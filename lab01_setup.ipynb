# %%
# LAB 1: Welcome to Machine Learning
# Student name: Tasnuba Tarannum Taha
# Student ID: 20245103071
print("Hello, future ML detective!")
print("Rule 1: The computer is literal, not rude.")
# Out:
# Hello, future ML detective!
# Rule 1: The computer is literal, not rude.

# %%
import numpy as np
np.random.seed(42)
marks = np.array([55, 72, 48, 90, 66, 81])
bonus=marks+5
print('Marks:', marks)
print('Minimum:', marks.min())
print('Mean:', marks.mean())
print('Standard deviation:', marks.std())
print('Bonus Marks:',bonus)
print('Passed:', marks[marks >= 50])
matrix = marks.reshape(2, 3)
print('Matrix:')
print(matrix)
# Out:
# Marks: [55 72 48 90 66 81]
# Minimum: 48
# Mean: 68.66666666666667
# Standard deviation: 14.372040758206733
# Bonus Marks: [60 77 53 95 71 86]
# Passed: [55 72 90 66 81]
# Matrix:
# [[55 72 48]
#  [90 66 81]]

# %%
import pandas as pd
print('Features = study_hours,sleep_hours,attendance,snacks')
print('Label = passed')
data = {
'student': ['Asha', 'Babu', 'Chayan', 'Dipa', 'Emon', 'Farah'],
'study_hours': [2, 5, 1, 7, 3, 6],
'sleep_hours': [8, 6, 9, 5, 7, 6],
'attendance': [70, 88, 55, 95, 75, 91],
'snacks': [3, 2, 5, 1, 4, 2],
'passed': ['Yes', 'Yes', 'No', 'Yes', 'No', 'Yes']
}
print("Samples:", df.shape[0])
print("Columns:", df.shape[1])
attendance_high = df[df['attendance'] >= 80]
display(attendance_high)
passed_students = df[df['passed'] == 'Yes']
average_study = passed_students['study_hours'].mean()
print("Average study hours:", average_study)
sorted_df = df.sort_values(by='attendance', ascending=False)
display(sorted_df)
print('No. This dataset does not prove causation.')
# df = pd.DataFrame(data)
#display(df)
#print(df.info())
#print(df.describe(numeric_only=True))
# Out:
# Features = study_hours,sleep_hours,attendance,snacks
# Label = passed
# Samples: 6
# Columns: 6
#   student  study_hours  sleep_hours  attendance  snacks passed
# 1    Babu            5            6          88       2    Yes
# 3    Dipa            7            5          95       1    Yes
# 5   Farah            6            6          91       2    Yes
# Average study hours: 5.0
#   student  study_hours  sleep_hours  attendance  snacks passed
# 3    Dipa            7            5          95       1    Yes
# 5   Farah            6            6          91       2    Yes
# 1    Babu            5            6          88       2    Yes
# 4    Emon            3            7          75       4     No
# 0    Asha            2            8          70       3    Yes
# 2  Chayan            1            9          55       5     No
# No. This dataset does not prove causation.

# %%
import random
import numpy as np
def generate_scores(use_seed):
    if use_seed:
      random.seed(42)
      np.random.seed(42)
    return np.random.randint(40, 101, size=5)
print('Seeded run 1:', generate_scores(True))
print('Seeded run 2:', generate_scores(True))
print('Unseeded run 1:', generate_scores(False))
print('Unseeded run 2:', generate_scores(False))
print('The seed problem in machine learning occurs because random processes such as splitting data into training and testing sets,')
print('can produce different results each time. If we use a fixed random seed,such as 42, the same random results are generated every time,making the experiment reproducible.')
print('Without a seed,different runs may produce different results and accuracy scores.')
print('Therefore,using the same seed helps researchers compare models fairly and ensures that their results can be repeated.')
# Out:
# Seeded run 1: [78 91 68 54 82]
# Seeded run 2: [78 91 68 54 82]
# Unseeded run 1: [ 47 100  60  78  97]
# Unseeded run 2: [58 62 50 50 63]
# The seed problem in machine learning occurs because random processes such as splitting data into training and testing sets,
# can produce different results each time. If we use a fixed random seed,such as 42, the same random results are generated every time,making the experiment reproducible.
# Without a seed,different runs may produce different results and accuracy scores.
# Therefore,using the same seed helps researchers compare models fairly and ensures that their results can be repeated.

# %% [markdown]
# Activity E:
# ## 1. Problem
#
# Question: What decision or prediction is needed?
#
# Answer:
# Predict whether a student passes or fails based on study hours, sleep hours, attendance, and snack purchases.
# ## 2. Data
#
# Question: Is the dataset relevant, legal, and documented?
#
# Answer:
# The dataset contains information about students, including study hours, sleep hours, attendance, snacks, and pass/fail status. It is suitable for a simple classification task.
# ## 3. Preparation
#
# Question: Are values missing, duplicated, biased, or leaked?
#
# Answer:
# The dataset was loaded into a Pandas DataFrame. Data inspection was performed using info() and describe(). No missing values or duplicates were observed in this small dataset.
# ## 4. Baseline
#
# Question: What simple method sets the minimum standard?
#
# Answer:
# A simple baseline could be predicting the most common class or using a basic classification model.
# ## 5. Evaluation
#
# Question: Which metric matches the real cost of errors?
#
# Answer:
# Accuracy can be used because the task is to classify students as passed or failed.
# ## 6. Improvement
#
# Question: What unique contribution is being tested?
#
# Answer:
# Possible improvements include collecting more data, adding new features, or testing different machine learning algorithms.
# ## 7. Communication
#
# Question: Can another person reproduce and understand it?
#
# Answer:
# The notebook should contain code, outputs, explanations, and observations so another person can reproduce the results.
